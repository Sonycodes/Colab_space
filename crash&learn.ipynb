# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonycodes/Colab_space/blob/main/crash%26learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium torch tensorboard

# %%
# !python train_cartpole.py
# Out:
# 2026-09-22 11:28:00.400243: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-22 11:28:00.495005: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Starting train_cartpole.py
# Init DQN
# Start training for 1000 episodes
# Episode   10  reward=   35.0  len=35    buf=  247
# Episode   20  reward=   16.0  len=16    buf=  437
# Episode   30  reward=   32.0  len=32    buf=  667
# Episode   40  reward=   33.0  len=33    buf=  874
# Episode   50  reward=   10.0  len=10    buf= 1111
# Episode   60  reward=   15.0  len=15    buf= 1273
# Episode   70  reward=   52.0  len=52    buf= 1534
# Episode   80  reward=   12.0  len=12    buf= 1815
# ...
